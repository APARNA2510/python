# %%
import pandas as pd

# %%
df = pd.read_csv('flipkart_laptop_Aug_22.csv')

# %%
df
# Out:
#      Unnamed: 0                                              title      price  \
# 0             0  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...    ₹38,990
# 1             1  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...    ₹54,990
# 2             2  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹35,990
# 3             3  ASUS Vivobook 15 Ryzen 7 Quad Core AMD R7-3700...    ₹46,990
# 4             4  MSI Modern 14 Core i5 10th Gen - (8 GB/512 GB ...    ₹41,990
# ..          ...                                                ...        ...
# 198         198  ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 ...    ₹50,990
# 199         199  ASUS ZenBook Duo 14 (2021) Touch Panel Intel E...  ₹1,14,990
# 200         200  acer Aspire 5 Core i5 11th Gen - (8 GB/512 GB ...    ₹59,090
# 201         201  DELL Inspiron Core i3 11th Gen - (8 GB/256 GB ...    ₹55,490
# 202         202  HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...    ₹41,290
#
# ...

# %%
df = pd.read_csv('flipkart_laptop_Aug_22.csv', index_col = 0)
df
# Out:
#                                                  title      price  \
# 0    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...    ₹38,990
# 1    Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...    ₹54,990
# 2    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹35,990
# 3    ASUS Vivobook 15 Ryzen 7 Quad Core AMD R7-3700...    ₹46,990
# 4    MSI Modern 14 Core i5 10th Gen - (8 GB/512 GB ...    ₹41,990
# ..                                                 ...        ...
# 198  ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 ...    ₹50,990
# 199  ASUS ZenBook Duo 14 (2021) Touch Panel Intel E...  ₹1,14,990
# 200  acer Aspire 5 Core i5 11th Gen - (8 GB/512 GB ...    ₹59,090
# 201  DELL Inspiron Core i3 11th Gen - (8 GB/256 GB ...    ₹55,490
# 202  HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...    ₹41,290
#
#                               rr  \
# 0    1,260 Ratings & 125 Reviews
# 1       188 Ratings & 17 Reviews
# 2    2,246 Ratings & 258 Reviews
# 3         63 Ratings & 4 Reviews
# ...

# %%
# selected cols
df = pd.read_csv('flipkart_laptop_Aug_22.csv',
    usecols=['title','price'])
df
# Out:
#                                                  title      price
# 0    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...    ₹38,990
# 1    Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...    ₹54,990
# 2    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹35,990
# 3    ASUS Vivobook 15 Ryzen 7 Quad Core AMD R7-3700...    ₹46,990
# 4    MSI Modern 14 Core i5 10th Gen - (8 GB/512 GB ...    ₹41,990
# ..                                                 ...        ...
# 198  ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 ...    ₹50,990
# 199  ASUS ZenBook Duo 14 (2021) Touch Panel Intel E...  ₹1,14,990
# 200  acer Aspire 5 Core i5 11th Gen - (8 GB/512 GB ...    ₹59,090
# 201  DELL Inspiron Core i3 11th Gen - (8 GB/256 GB ...    ₹55,490
# 202  HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...    ₹41,290
#
# [203 rows x 2 columns]

# %%
# limit number of rows to be read
df = pd.read_csv('flipkart_laptop_Aug_22.csv',
    usecols=['title','price','rr'],
    nrows=100)
df
# Out:
#                                                 title    price  \
# 0   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  ₹38,990
# 1   Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  ₹54,990
# 2   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹35,990
# 3   ASUS Vivobook 15 Ryzen 7 Quad Core AMD R7-3700...  ₹46,990
# 4   MSI Modern 14 Core i5 10th Gen - (8 GB/512 GB ...  ₹41,990
# ..                                                ...      ...
# 95  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...  ₹57,990
# 96  DELL Core i5 11th Gen - (16 GB/512 GB SSD/Wind...  ₹74,490
# 97  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...  ₹59,990
# 98  ASUS VivoBook K15 OLED (2022) Ryzen 5 Hexa Cor...  ₹63,990
# 99  Lenovo IdeaPad Gaming 3i Core i7 11th Gen - (8...  ₹72,990
#
#                              rr
# 0   1,260 Ratings & 125 Reviews
# 1      188 Ratings & 17 Reviews
# 2   2,246 Ratings & 258 Reviews
# 3        63 Ratings & 4 Reviews
# 4     867 Ratings & 108 Reviews
# ...

# %%
# read the data
df = pd.read_csv('flipkart_laptop_Aug_22.csv', index_col = 0)

# %%
# viewing and understanding the data
df.head() # first 5 rows
# Out:
#                                                title    price  \
# 0  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  ₹38,990
# 1  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  ₹54,990
# 2  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹35,990
# 3  ASUS Vivobook 15 Ryzen 7 Quad Core AMD R7-3700...  ₹46,990
# 4  MSI Modern 14 Core i5 10th Gen - (8 GB/512 GB ...  ₹41,990
#
#                             rr  \
# 0  1,260 Ratings & 125 Reviews
# 1     188 Ratings & 17 Reviews
# 2  2,246 Ratings & 258 Reviews
# 3       63 Ratings & 4 Reviews
# 4    867 Ratings & 108 Reviews
#
#                                                 link  \
# 0  /lenovo-ideapad-3-core-i3-11th-gen-8-gb-512-gb...
# 1  /lenovo-ideapad-gaming-core-i5-11th-gen-8-gb-5...
# 2  /asus-vivobook-15-2022-core-i3-10th-gen-8-gb-5...
# 3  /asus-vivobook-15-ryzen-7-quad-core-amd-r7-370...
# 4  /msi-modern-14-core-i5-10th-gen-8-gb-512-gb-ss...
#
#                                             img_link  \
# ...

# %%
df.tail() # bottom 5 rows
# Out:
#                                                  title      price  \
# 198  ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 ...    ₹50,990
# 199  ASUS ZenBook Duo 14 (2021) Touch Panel Intel E...  ₹1,14,990
# 200  acer Aspire 5 Core i5 11th Gen - (8 GB/512 GB ...    ₹59,090
# 201  DELL Inspiron Core i3 11th Gen - (8 GB/256 GB ...    ₹55,490
# 202  HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...    ₹41,290
#
#                               rr  \
# 198  1,768 Ratings & 174 Reviews
# 199       12 Ratings & 2 Reviews
# 200     284 Ratings & 30 Reviews
# 201     222 Ratings & 21 Reviews
# 202  2,112 Ratings & 229 Reviews
#
#                                                   link  \
# 198  /asus-vivobook-15-2022-core-i5-11th-gen-8-gb-1...
# 199  /asus-zenbook-duo-14-2021-touch-panel-intel-ev...
# 200  /acer-aspire-5-core-i5-11th-gen-8-gb-512-gb-ss...
# 201  /dell-inspiron-core-i3-11th-gen-8-gb-256-gb-ss...
# 202  /hp-core-i3-11th-gen-8-gb-256-gb-ssd-windows-1...
#
# ...

# %%
df.tail(6)
# Out:
#                                                  title      price  \
# 197  Lenovo IdeaPad 5 Pro Core i5 11th Gen - (16 GB...    ₹67,990
# 198  ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 ...    ₹50,990
# 199  ASUS ZenBook Duo 14 (2021) Touch Panel Intel E...  ₹1,14,990
# 200  acer Aspire 5 Core i5 11th Gen - (8 GB/512 GB ...    ₹59,090
# 201  DELL Inspiron Core i3 11th Gen - (8 GB/256 GB ...    ₹55,490
# 202  HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...    ₹41,290
#
#                               rr  \
# 197       17 Ratings & 2 Reviews
# 198  1,768 Ratings & 174 Reviews
# 199       12 Ratings & 2 Reviews
# 200     284 Ratings & 30 Reviews
# 201     222 Ratings & 21 Reviews
# 202  2,112 Ratings & 229 Reviews
#
#                                                   link  \
# 197  /lenovo-ideapad-5-pro-core-i5-11th-gen-16-gb-5...
# 198  /asus-vivobook-15-2022-core-i5-11th-gen-8-gb-1...
# 199  /asus-zenbook-duo-14-2021-touch-panel-intel-ev...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 203 entries, 0 to 202
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     203 non-null    object
#  1   price     203 non-null    object
#  2   rr        203 non-null    object
#  3   link      203 non-null    object
#  4   img_link  203 non-null    object
#  5   details   203 non-null    object
# dtypes: object(6)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#                                                     title    price  \
# count                                                 203      203
# unique                                                174      123
# top     ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...  ₹34,990
# freq                                                    5        5
#
#                            rr  \
# count                     203
# unique                    156
# top     3 Ratings & 0 Reviews
# freq                        4
#
#                                                      link  \
# count                                                 203
# unique                                                203
# top     /lenovo-ideapad-3-core-i3-11th-gen-8-gb-512-gb...
# freq                                                    1
#
#                                                  img_link  \
# count                                                 203
# ...
